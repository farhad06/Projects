# %%
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
stop_words = set(stopwords.words('bengali'))
print(len(stop_words))
print(stop_words)
# print(len(stop_words))
# Out:
# 398
# {'এই', 'গেছে', 'হলো', 'ছাড়াও', 'বিশেষ', 'কয়েক', 'বাদে', 'যাওয়া', 'আরও', 'করলে', 'হলে', 'যেতে', 'নেওয়ার', 'নয়', 'কেন', 'থেকেই', 'পারে', 'অথবা', 'স্বয়ং', 'উত্তর', 'কাউকে', 'এবং', 'নয়', 'যথেষ্ট', 'করবে', 'কাজ', 'এখনও', 'করবেন', 'আপনার', 'এখন', 'আগেই', 'পক্ষে', 'যে', 'তাঁদের', 'মাত্র', 'করায়', 'তবে', 'রকম', 'ওই', 'বলল', 'বলেন', 'গেলে', 'ওরা', 'করা', 'সুতরাং', 'দুই', 'আবার', 'দ্বারা', 'জানানো', 'বিভিন্ন', 'করছে', 'বলে', 'তারপর', 'তাহা', 'তুলে', 'পারেন', 'সাধারণ', 'বলতে', 'হওয়া', 'করিয়ে', 'আগামী', 'যারা', 'নিয়ে', 'ছিল', 'করেছে', 'পাচ', 'বার', 'কি', 'এমন', 'এস', 'যাতে', 'ওঁরা', 'দেখা', 'এতটাই', 'থাকবেন', 'বলেছেন', 'বদলে', 'প্রায়', 'ওর', 'যাবে', 'তিনঐ', 'দু', 'ওঁদের', 'তাঁরা', 'করি', 'দিকে', 'সেই', 'যিনি', 'এবার', 'পরেই', 'এটা', 'হয়েছিল', 'করিতে', 'ও', 'জনের', 'কমনে', 'ইহা', 'করতে', 'কেউই', 'রয়েছে', 'কিছু', 'নেই', 'যার', 'এ', 'মধ্যে', 'হতেই', 'করছেন', 'সি', 'এর', 'ভাবেই', 'অতএব', 'কিছুই', 'করার', 'হচ্ছে', 'নিজে', 'বেশি', 'সহ', 'যেমন', 'আগে', 'কবে', 'দিয়ে', 'এতে', 'তাঁকে', 'তাহলে', 'আমরা', 'বন', 'উচিত', 'বললেন', 'সমস্ত', 'যখন', 'হাজার', 'জানা', 'এঁদের', 'হয়েই', 'হন', 'আমাদের', 'বসে', 'মধ্যভাগে', 'নানা', 'গিয়েছে', 'অনেকে', 'কাজে', 'উপরে', 'নাই', 'ওদের', 'টি', 'তেমন', 'জন্য', 'এঁরা', 'আমার', 'নিজের', 'কারণ', 'যাকে', 'যান', 'জানিয়েছে', 'কেউ', 'কোটি', 'নতুন', 'এরা', 'দিয়েছেন', 'ইত্যাদি', 'নিজেই', 'দেওয়ার', 'আর', 'কখনও', 'থাকবে', 'বিষয়টি', 'চার', 'বেশ', 'এটাই', 'তারা', 'তিনি', 'দুটি', 'দিয়েছে', 'একে', 'হোক', 'তোমার', 'গেল', 'তাতে', 'জ্নজন', 'হয়েছে', 'একবার', 'স্পষ্ট', 'সহিত', 'নিজেদের', 'তো', 'দিতে', 'পেয়্র্', 'এত', 'পরে', 'থাকেন', 'এখানেই', 'র', 'জন্যওজে', 'সে', 'কিন্তু', 'তাও', 'ধরে', 'আদ্যভাগে', 'ঠিক', 'যদি', 'অন্তত', 'সবার', 'মাধ্যমে', 'যতটা', 'আপনি', 'সেখানে', 'শুরু', 'এব', 'তত', 'হয়ে', 'বিনা', 'এদের', 'হলেও', 'তুমি', 'হৈলে', 'এমনি', 'নেওয়া', 'হইবে', 'বরং', 'ক্ষেত্রে', 'তাহার', 'আমি', 'গোটা', 'তাঁর', 'করেই', 'সামনে', 'করলেন', 'চান', 'প্রাথমিক', 'এসে', 'যত', 'তার', 'দেওয়া', 'গিয়ে', 'আজ', 'ভাবে', 'সঙ্গেও', 'থেকেও', 'পাওয়া', 'দেখতে', 'সেটি', 'এখানে', 'পর', 'যদিও', 'মোট', 'হইয়া', 'জানিয়ে', 'জনকে', 'প্রায়', 'চালু', 'ছাড়া', 'অনেকেই', 'থাকায়', 'দেওয়া', 'পারি', 'দেন', 'এটি', 'কেখা', 'হয়তো', 'বহু', 'করেছেন', 'কত', 'থেকে', 'থাকা', 'না', 'ধামার', 'ব্যবহার', 'পরেও', 'তখন', 'হলেই', 'অনুযায়ী', 'অনেক', 'মতো', 'হল', 'মতোই', 'গুলি', 'তা', 'তারৈ', 'বলা', 'অর্থাত', 'কয়েক', 'প্রতি', 'এল', 'হয়', 'এক্', 'একটি', 'তিনিও', 'জানতে', 'নিতে', 'ঐ', 'কোনও', 'সব', 'তাকে', 'সেখান', 'ওকে', 'পি', 'জানায়', 'প্রভৃতি', 'শুধু', 'যায়', 'হয়', 'জে', 'এমনকী', 'কোন', 'যাওয়া', 'লক্ষ', 'সম্প্রতি', 'তাই', 'হবেন', 'করেছিলেন', 'দেয়', 'উপর', 'নেওয়া', 'রাখা', 'তাঁাহারা', 'যাঁরা', 'হতে', 'তাদের', 'মোটেই', 'চেষ্টা', 'ধরা', 'একই', 'যেখানে', 'বি', 'হওয়ায়', 'বা', 'তবু', 'কাছ', 'রেখে', 'প্রযন্ত', 'যাঁর', 'আমাকে', 'আই', 'ফলে', 'মধ্যেও', 'পেয়ে', 'চলে', 'নাকি', 'মধ্যেই', 'যাচ্ছে', 'হত', 'অন্য', 'কিংবা', 'প্রথম', 'দুটো', 'থাকে', 'করিয়া', 'হয়েছেন', 'পর্যন্ত', 'ওঁর', 'দিলেন', 'করে', 'হইতে', 'কী', 'কারও', 'জন', 'যাওয়ার', 'যেন', 'কাছে', 'ওখানে', 'বক্তব্য', 'হওয়ার', 'কোনো', 'কে', 'হবে', 'নিয়ে', 'দিন', 'গিয়ে', 'তাহাতে', 'করেন', 'ছিলেন', 'করাই', 'নাগাদ', 'যা', 'ফের', 'মনে', 'যাদের', 'ফিরে', 'অবধি', 'উনি', 'সেটাও', 'খুব', 'চায়', 'সেটাই', 'অবশ্য', 'তথা', 'সঙ্গে', 'হিসাবে', 'চেয়ে', 'ই', 'ব্যাপারে', 'সেটা', 'আছে', 'অথচ', 'কয়েকটি', 'দেখে', 'হয়নি'}
